# %%
"""
import all the necessary libraries for data cleaning, analysis and visualisation
"""

from scipy import stats
import numpy as np
import pandas as pd
import scipy.stats as st
from statsmodels.stats.weightstats import ztest

# reads the cleaned dataset 2 for hypothesis testing
df = pd.read_csv('dataset2_cleaned_V2.csv')

# %%
dataset_split_parameter = ['rat_arrival_number', 'rat_minutes']
test_column = ['bat_landing_number', 'food_availability','hours_after_sunset']

# %%
for x in dataset_split_parameter:
    for y in test_column:
        """
        Splits the DataFrame into two sections.
        Section 1: where x is > 0
        Section 2: where x is = 0
        """

        # Converts the x column to integers
        df[x] = df[x].astype(int)

        # Creates two dataframes as per the two sections
        df_above_zero = df[df[x] > 0]
        df_zero = df[df[x] == 0]

        # Calculate mean and standard deviation for each section
        mean_1 = df_above_zero[y].mean()
        std_1 = df_above_zero[y].std()
        n_1 = len(df_above_zero[y])

        mean_2 = df_zero[y].mean()
        std_2 = df_zero[y].std()
        n_2 = len(df_zero[y])

        # Print the results
        print(f"""
        \nfor {y} when the dataset is split using {x}:

        \tRats -
        \tMean: {mean_1:.2f}
        \tStandard Deviation: {std_1:.2f}
        \tSamples: {n_1}

        \tNo Rats -
        \tMean: {mean_2:.2f}
        \tStandard Deviation: {std_2:.2f}
        \tSamples: {n_2}
        """)

        # Perform Z-test
        z_stats, p_val = ztest(df_above_zero[y], df_zero[y], alternative='two-sided')

        print(f"""
        \tComputing z* ...
        \tz-statistic (t*): {z_stats:.2f}

        \tComputing p-value ...
        \tp-value: {p_val:.10f}

        \tConclusion: {"We reject the null hypothesis." if p_val < 0.05 else "We accept the null hypothesis."}
        """)
# Out:
#
# for bat_landing_number when the dataset is split using rat_arrival_number:
#
#         	Rats -
#         	Mean: 29.14
#         	Standard Deviation: 22.29
#         	Samples: 497
#
#         	No Rats -
#         	Mean: 34.61
#         	Standard Deviation: 23.91
#         	Samples: 1400
#
#
#         	Computing z* ...
#         	z-statistic (t*): -4.46
#
#         	Computing p-value ...
#         	p-value: 0.0000081400
#
#         	Conclusion: We reject the null hypothesis.
#
#
#
# for food_availability when the dataset is split using rat_arrival_number:
#
#         	Rats -
#         	Mean: 2.52
#         	Standard Deviation: 0.85
#         	Samples: 497
#
#         	No Rats -
#         	Mean: 2.77
#         	Standard Deviation: 1.01
#         	Samples: 1400
#
#
#         	Computing z* ...
#         	z-statistic (t*): -5.08
#
#         	Computing p-value ...
#         	p-value: 0.0000003804
#
#         	Conclusion: We reject the null hypothesis.
#
#
#
# for hours_after_sunset when the dataset is split using rat_arrival_number:
#
#         	Rats -
#         	Mean: 5.64
#         	Standard Deviation: 3.52
#         	Samples: 497
#
#         	No Rats -
#         	Mean: 4.37
#         	Standard Deviation: 3.85
#         	Samples: 1400
#
#
#         	Computing z* ...
#         	z-statistic (t*): 6.43
#
#         	Computing p-value ...
#         	p-value: 0.0000000001
#
#         	Conclusion: We reject the null hypothesis.
#
#
#
# for bat_landing_number when the dataset is split using rat_minutes:
#
#         	Rats -
#         	Mean: 27.68
#         	Standard Deviation: 21.92
#         	Samples: 424
#
#         	No Rats -
#         	Mean: 34.76
#         	Standard Deviation: 23.85
#         	Samples: 1473
#
#
#         	Computing z* ...
#         	z-statistic (t*): -5.48
#
#         	Computing p-value ...
#         	p-value: 0.0000000427
#
#         	Conclusion: We reject the null hypothesis.
#
#
#
# for food_availability when the dataset is split using rat_minutes:
#
#         	Rats -
#         	Mean: 2.51
#         	Standard Deviation: 0.82
#         	Samples: 424
#
#         	No Rats -
#         	Mean: 2.76
#         	Standard Deviation: 1.01
#         	Samples: 1473
#
#
#         	Computing z* ...
#         	z-statistic (t*): -4.74
#
#         	Computing p-value ...
#         	p-value: 0.0000021128
#
#         	Conclusion: We reject the null hypothesis.
#
#
#
# for hours_after_sunset when the dataset is split using rat_minutes:
#
#         	Rats -
#         	Mean: 5.69
#         	Standard Deviation: 3.50
#         	Samples: 424
#
#         	No Rats -
#         	Mean: 4.42
#         	Standard Deviation: 3.85
#         	Samples: 1473
#
#
#         	Computing z* ...
#         	z-statistic (t*): 6.07
#
#         	Computing p-value ...
#         	p-value: 0.0000000013
#
#         	Conclusion: We reject the null hypothesis.
